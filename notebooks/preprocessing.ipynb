# %%
import pandas as pd
import glob
import os
import numpy as np
from pathlib import Path
from datetime import datetime

# %% [markdown]
# ## Tính tỷ lệ FF

# %%
import glob
import os
import pandas as pd
from pathlib import Path
from datetime import datetime

def process_free_float_data(tennganh, external_market_cap_file=None):
    folder_path = Path(f"D:\\nckh\\data\\{tennganh}")
    excel_files = glob.glob(str(folder_path / "*.xlsx"))

    if not excel_files:
        print(f"No .xlsx files found in {folder_path}")
        return None

    dataframes = []
    for file in excel_files:
        print(f"Reading {file}...")
        try:
            df = pd.read_excel(file, header=7)
            df['SourceFile'] = os.path.basename(file)
            dataframes.append(df)
        except (pd.errors.ParserError, FileNotFoundError) as e:
            print(f"Error reading {file}: {e}")
            continue

    if not dataframes:
        print(f"No valid DataFrames created from files in {folder_path}")
        return None

    df = pd.concat(dataframes, ignore_index=True)

    # Drop rows with all critical metadata missing
    initial_rows = len(df)
    df = df.dropna(subset=['STT','Mã', 'Tên công ty', 'Ngày'], how='all')
    print(f"Dropped {initial_rows - len(df)} rows with missing Stock_Code, Company_Name, and Date.")

    # Standardize column names
    df = df.rename(columns={
        'Số CP Free Float\nĐơn vị: Cổ phiếu': 'Free_Float',
        'Số CP lưu hành hiện thời\nĐơn vị: Cổ phiếu': 'Luu_Hanh',
        'Số CP niêm yết\nĐơn vị: Cổ phiếu': 'Niem_Yet',
        'Ngày': 'Date',
        'Mã': 'Stock_Code',
        'Tên công ty': 'Company_Name',
        'Vốn hóa thị trường\nĐơn vị: VND': 'Market_Cap',
        'STT': 'Index',
        'SourceFile': 'Source_File'
    })

    # Convert data types
    numeric_cols = ['STT','Free_Float', 'Luu_Hanh', 'Niem_Yet', 'Market_Cap']
    for col in numeric_cols:
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors='coerce')
    df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

    # Merge external Market_Cap if provided
    if external_market_cap_file:
        print(f"Loading external Market_Cap from {external_market_cap_file}")
        external_data = pd.read_csv(external_market_cap_file)
        external_data['Date'] = pd.to_datetime(external_data['Date'], errors='coerce')
        external_data = external_data[['Stock_Code', 'Date', 'Market_Cap']]
        df = df.drop(columns=['Market_Cap'], errors='ignore')
        df = df.merge(external_data, on=['Stock_Code', 'Date'], how='left')
        print("\n=== External Market_Cap Merged ===")
        print(df[['Stock_Code', 'Date', 'Market_Cap']].head())

    # Print initial structure
    print("\n=== First 5 rows ===")
    print(df.head())
    print("\n=== Column names and info ===")
    print(df.info())

    # Log missing data
    print("\n=== Missing Data Summary ===")
    for col in df.columns:
        missing_count = df[col].isna().sum()
        if missing_count > 0:
            print(f"Column {col}: {missing_count} missing values")

    # Investigate missing Free_Float
    if df['Free_Float'].isna().any():
        print("\n=== Stocks with Missing Free_Float ===")
        print(df[df['Free_Float'].isna()]['Stock_Code'].value_counts().head())
        print("\n=== Dates with Missing Free_Float ===")
        print(df[df['Free_Float'].isna()]['Date'].value_counts().sort_index().head())

    # Sort by Stock_Code and Date for consistent filling
    df = df.sort_values(['Stock_Code', 'Date'])

    # Apply ffill within Stock_Code
    for col in ['Free_Float', 'Luu_Hanh', 'Market_Cap']:
        if col in df.columns and df[col].isna().any():
            print(f"Applying ffill to {col} within Stock_Code.")
            df[col] = df.groupby('Stock_Code')[col].ffill()

    # Drop remaining missing values
    missing_free_float = df['Free_Float'].isna().sum()
    missing_market_cap = df['Market_Cap'].isna().sum()
    missing_luu_hanh = df['Luu_Hanh'].isna().sum()
    if missing_free_float > 0 or missing_market_cap > 0 or missing_luu_hanh > 0:
        print(f"Dropping {missing_free_float} rows with missing Free_Float, {missing_market_cap} rows with missing Market_Cap, and {missing_luu_hanh} rows with missing Luu_Hanh.")
        df = df.dropna(subset=['Free_Float', 'Market_Cap', 'Luu_Hanh'])

    # Handle invalid dates
    invalid_dates = df['Date'].isna().sum()
    if invalid_dates > 0:
        print(f"Dropping {invalid_dates} rows with invalid dates.")
        df = df.dropna(subset=['Date'])

    # Filter invalid data
    df_long = df[df['Luu_Hanh'] > 0]
    dropped_luu_hanh = len(df) - len(df_long)
    if dropped_luu_hanh > 0:
        print(f"Dropped {dropped_luu_hanh} rows with Luu_Hanh <= 0.")
    df_long = df_long[df_long['Free_Float'] <= df_long['Luu_Hanh']]
    df_long = df_long[df_long['Free_Float'] >= 0]

    # Log data retention
    print(f"\nRemaining rows after filtering: {len(df_long)} ({len(df_long)/initial_rows*100:.2f}% of original)")
    print(f"Unique stocks: {df_long['Stock_Code'].nunique()}")
    print(f"Unique dates: {df_long['Date'].nunique()}")

    print("\n=== After Pre-Processing ===")
    print(df_long.head())
    print("\n=== Debug Data ===")
    print("Total Free_Float = 0:", (df_long['Free_Float'] == 0).sum())
    print("Total Luu_Hanh = 0:", (df_long['Luu_Hanh'] == 0).sum())
    print("Free_Float sum by Date:", df_long.groupby('Date')['Free_Float'].sum().head())
    print("Luu_Hanh sum by Date:", df_long.groupby('Date')['Luu_Hanh'].sum().head())
    print("\n=== Missing Data After Preprocessing ===")
    print(df_long.isna().sum())

    # Calculate industry Free Float ratio
    nghanh_freefloat = df_long.groupby('Date').apply(
        lambda x: x['Free_Float'].sum() / x['Luu_Hanh'].sum() if x['Luu_Hanh'].sum() != 0 else 0
    )
    zero_luu_hanh_dates = df_long.groupby('Date').filter(lambda x: x['Luu_Hanh'].sum() == 0)['Date'].unique()
    for date in zero_luu_hanh_dates:
        print(f"Warning: Zero Luu_Hanh sum for date {date}")
    nghanh_freefloat = pd.DataFrame(nghanh_freefloat, columns=['Tỷ lệ FF']).reset_index()

    # # Calculate adjusted market cap
    # df_long = df_long.merge(nghanh_freefloat, on='Date', how='left')
    # df_long['Adjusted_Market_Cap'] = df_long['Market_Cap'] * df_long['Tỷ lệ FF']

    # # Print results
    # print(f"\n=== TỶ LỆ FREE FLOAT NGÀNH ({tennganh}) ===")
    # print(nghanh_freefloat.head(10))
    # print("\n=== Adjusted Market Cap (First 5 rows) ===")
    # print(df_long[['Date', 'Stock_Code', 'Market_Cap', 'Tỷ lệ FF', 'Adjusted_Market_Cap']].head())

    # Save results with timestamp
    output = f'ty_le_freefloat_{tennganh}'
    output_path = Path("data") / "processed" / f"{output}.xlsx"
    os.makedirs(output_path.parent, exist_ok=True)
    nghanh_freefloat.to_excel(output_path, index=False)

    # output_adj = f'adjusted_market_cap_{tennganh}_{timestamp}'
    # output_adj_path = Path("data") / "processed" / f"{output_adj}.xlsx"
    # df_long[['Date', 'Stock_Code', 'Company_Name', 'Free_Float', 'Luu_Hanh', 'Market_Cap', 'Tỷ lệ FF', 'Adjusted_Market_Cap']].to_excel(output_adj_path, index=False)

    return df_long, nghanh_freefloat

if __name__ == "__main__":
    list_nganh = ['hangtieudung', 'duocphamyte', 'taichinh', 'nganhang', 'congnghiep', 
                  'dichvutieudung', 'tienichcd', 'nguyenvatlieu', 'vienthong', 'cntt']
    # Replace with the path to your external Market_Cap file
    # external_file = "D:\\nckh\\data\\external_market_cap.csv"  # Update this path
    for nganh in list_nganh:
        result_df, result_ff = process_free_float_data(nganh)
        if result_df is not None:
            print(f"Processing completed. {nganh} results saved to files.")
# Out:
# Reading D:\nckh\data\hangtieudung\hangtieudung_1.xlsx...
# Reading D:\nckh\data\hangtieudung\hangtieudung_2.xlsx...
# Reading D:\nckh\data\hangtieudung\hangtieudung_3.xlsx...
# Reading D:\nckh\data\hangtieudung\hangtieudung_4.xlsx...
# Reading D:\nckh\data\hangtieudung\hangtieudung_5.xlsx...
# Reading D:\nckh\data\hangtieudung\hangtieudung_6.xlsx...
# Reading D:\nckh\data\hangtieudung\hangtieudung_7.xlsx...
# Dropped 21 rows with missing Stock_Code, Company_Name, and Date.
#
# === First 5 rows ===
#   Index Stock_Code               Company_Name       Date   Free_Float  \
# 0     1        CTF                  City Auto 2025-10-01   43044236.0
# 1     2        CTP            Hoà Bình Takara 2025-10-01    7864994.0
# 2     3        DAS   Thiết bị Dầu khí Đà Nẵng 2025-10-01    2310000.0
# 3     4        DAT  ĐT Du lịch và PT Thủy sản 2025-10-01    8999684.0
# 4     5        DBC            Tập đoàn DABACO 2025-10-01  250163333.0
#
#       Luu_Hanh     Niem_Yet    Market_Cap          Source_File
# 0   95653859.0   95653859.0  1.984818e+12  hangtieudung_1.xlsx
# 1   12099992.0   12099992.0  1.234199e+11  hangtieudung_1.xlsx
# 2    4200000.0    4200000.0  4.536000e+10  hangtieudung_1.xlsx
# 3   69228341.0   69228341.0  7.234362e+11  hangtieudung_1.xlsx
# 4  384866667.0  384866667.0  1.054535e+13  hangtieudung_1.xlsx
#
# === Column names and info ===
# <class 'pandas.core.frame.DataFrame'>
# Index: 967151 entries, 0 to 967171
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Index         967151 non-null  object
#  1   Stock_Code    967095 non-null  object
#  2   Company_Name  967095 non-null  object
#  3   Date          967095 non-null  datetime64[ns]
#  4   Free_Float    819797 non-null  float64
#  5   Luu_Hanh      924224 non-null  float64
#  6   Niem_Yet      819797 non-null  float64
#  7   Market_Cap    838381 non-null  float64
#  8   Source_File   967151 non-null  object
# dtypes: datetime64[ns](1), float64(4), object(4)
# memory usage: 73.8+ MB
# None
#
# === Missing Data Summary ===
# Column Stock_Code: 56 missing values
# Column Company_Name: 56 missing values
# Column Date: 56 missing values
# Column Free_Float: 147354 missing values
# Column Luu_Hanh: 42927 missing values
# Column Niem_Yet: 147354 missing values
# Column Market_Cap: 128770 missing values
#
# === Stocks with Missing Free_Float ===
# Stock_Code
# FBT    1482
# BHS    1482
# BAS    1482
# NPS    1482
# AGC    1476
# Name: count, dtype: int64
#
# === Dates with Missing Free_Float ===
# Date
# 2008-12-23     45
# 2008-12-24     45
# 2008-12-25     46
# 2008-12-27     46
# 2008-12-31    131
# Name: count, dtype: int64
# Applying ffill to Free_Float within Stock_Code.
# Applying ffill to Luu_Hanh within Stock_Code.
# Applying ffill to Market_Cap within Stock_Code.
# Dropping 136061 rows with missing Free_Float, 2202 rows with missing Market_Cap, and 6475 rows with missing Luu_Hanh.
# Dropped 101282 rows with Luu_Hanh <= 0.
#
# Remaining rows after filtering: 729356 (75.41% of original)
# Unique stocks: 314
# Unique dates: 2772
#
# === After Pre-Processing ===
#         Index Stock_Code     Company_Name       Date  Free_Float   Luu_Hanh  \
# 901604  62400        AGC  An Giang Coffee 2014-08-27   7904400.0  8300000.0
# 901599  62395        AGC  An Giang Coffee 2014-08-28   7904400.0  8300000.0
# 901594  62390        AGC  An Giang Coffee 2014-08-29   7904400.0  8300000.0
# 901589  62385        AGC  An Giang Coffee 2014-09-03   7904400.0  8300000.0
# 901584  62380        AGC  An Giang Coffee 2014-09-04   7904400.0  8300000.0
#
#          Niem_Yet  Market_Cap          Source_File
# 901604  8300000.0         0.0  hangtieudung_6.xlsx
# 901599  8300000.0         0.0  hangtieudung_6.xlsx
# 901594  8300000.0         0.0  hangtieudung_6.xlsx
# 901589  8300000.0         0.0  hangtieudung_6.xlsx
# 901584  8300000.0         0.0  hangtieudung_6.xlsx
#
# === Debug Data ===
# Total Free_Float = 0: 245503
# Total Luu_Hanh = 0: 0
# Free_Float sum by Date: Date
# 2014-08-27    2.240382e+09
# 2014-08-28    2.240382e+09
# 2014-08-29    2.240740e+09
# 2014-09-03    2.240740e+09
# 2014-09-04    2.240790e+09
# Name: Free_Float, dtype: float64
# Luu_Hanh sum by Date: Date
# 2014-08-27    5.876340e+09
# 2014-08-28    5.876340e+09
# 2014-08-29    5.877237e+09
# 2014-09-03    5.877237e+09
# 2014-09-04    5.877419e+09
# Name: Luu_Hanh, dtype: float64
#
# === Missing Data After Preprocessing ===
# Index              0
# Stock_Code         0
# Company_Name       0
# Date               0
# Free_Float         0
# Luu_Hanh           0
# Niem_Yet        8772
# Market_Cap         0
# Source_File        0
# dtype: int64
# C:\Users\caida\AppData\Local\Temp\ipykernel_7376\3003727649.py:135: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   nghanh_freefloat = df_long.groupby('Date').apply(
# Processing completed. hangtieudung results saved to files.
# Reading D:\nckh\data\duocphamyte\duocphamyte1.xlsx...
# Reading D:\nckh\data\duocphamyte\duocphamyte2.xlsx...
# Dropped 6 rows with missing Stock_Code, Company_Name, and Date.
#
# === First 5 rows ===
#   Index Stock_Code           Company_Name       Date   Free_Float  \
# 0     1        AGP  Dược phẩm AGIMEXPHARM 2025-10-01   11976871.0
# 1     2        AMP              Armephaco 2025-10-01    1950000.0
# 2     3        AMV   Dược-TB Y tế Việt Mỹ 2025-10-01  131105650.0
# 3     4        APC        Chiếu xạ An Phú 2025-10-01   19905025.0
# 4     5        BCH          Dược Bảo Châu 2025-10-01          0.0
#
#       Luu_Hanh    Market_Cap     Niem_Yet        Source_File
# 0   26615268.0  1.102910e+12   26615268.0  duocphamyte1.xlsx
# 1   13000000.0  1.729000e+11   13000000.0  duocphamyte1.xlsx
# 2  131105650.0  2.622113e+11  131105650.0  duocphamyte1.xlsx
# 3   19905025.0  1.498052e+11   20121395.0  duocphamyte1.xlsx
# 4   21500000.0           NaN   21500000.0  duocphamyte1.xlsx
#
# === Column names and info ===
# <class 'pandas.core.frame.DataFrame'>
# Index: 235068 entries, 0 to 235073
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Index         235068 non-null  object
#  1   Stock_Code    235052 non-null  object
#  2   Company_Name  235052 non-null  object
#  3   Date          235052 non-null  datetime64[ns]
#  4   Free_Float    202198 non-null  float64
#  5   Luu_Hanh      226934 non-null  float64
#  6   Market_Cap    216247 non-null  float64
#  7   Niem_Yet      202198 non-null  float64
#  8   Source_File   235068 non-null  object
# dtypes: datetime64[ns](1), float64(4), object(4)
# memory usage: 17.9+ MB
# None
#
# === Missing Data Summary ===
# Column Stock_Code: 16 missing values
# Column Company_Name: 16 missing values
# Column Date: 16 missing values
# Column Free_Float: 32870 missing values
# Column Luu_Hanh: 8134 missing values
# Column Market_Cap: 18821 missing values
# Column Niem_Yet: 32870 missing values
#
# === Stocks with Missing Free_Float ===
# Stock_Code
# DHG    1405
# DMC    1404
# DCL    1404
# IMP    1404
# OPC    1404
# Name: count, dtype: int64
#
# === Dates with Missing Free_Float ===
# Date
# 2008-12-23     7
# 2008-12-24     7
# 2008-12-25     7
# 2008-12-27     7
# 2008-12-31    31
# Name: count, dtype: int64
# Applying ffill to Free_Float within Stock_Code.
# Applying ffill to Luu_Hanh within Stock_Code.
# Applying ffill to Market_Cap within Stock_Code.
# Dropping 31208 rows with missing Free_Float, 312 rows with missing Market_Cap, and 2353 rows with missing Luu_Hanh.
# Dropped 17966 rows with Luu_Hanh <= 0.
#
# Remaining rows after filtering: 185894 (79.08% of original)
# Unique stocks: 79
# Unique dates: 2772
#
# === After Pre-Processing ===
#          Index Stock_Code           Company_Name       Date  Free_Float  \
# 142117  142118        AGP  Dược phẩm AGIMEXPHARM 2015-05-28         0.0
# 142072  142073        AGP  Dược phẩm AGIMEXPHARM 2015-05-29         0.0
# 142027  142028        AGP  Dược phẩm AGIMEXPHARM 2015-06-01         0.0
# 141982  141983        AGP  Dược phẩm AGIMEXPHARM 2015-06-02         0.0
# 141937  141938        AGP  Dược phẩm AGIMEXPHARM 2015-06-03         0.0
#
#          Luu_Hanh  Market_Cap  Niem_Yet        Source_File
# 142117  2200000.0         0.0       0.0  duocphamyte1.xlsx
# 142072  2200000.0         0.0       0.0  duocphamyte1.xlsx
# 142027  2200000.0         0.0       0.0  duocphamyte1.xlsx
# 141982  2200000.0         0.0       0.0  duocphamyte1.xlsx
# 141937  2200000.0         0.0       0.0  duocphamyte1.xlsx
#
# === Debug Data ===
# Total Free_Float = 0: 51427
# Total Luu_Hanh = 0: 0
# Free_Float sum by Date: Date
# 2014-08-27    220476596.0
# 2014-08-28    220476596.0
# 2014-08-29    220476596.0
# 2014-09-03    220476596.0
# 2014-09-04    220476596.0
# Name: Free_Float, dtype: float64
# Luu_Hanh sum by Date: Date
# 2014-08-27    424926895.0
# 2014-08-28    424926895.0
# 2014-08-29    424926895.0
# 2014-09-03    424926895.0
# 2014-09-04    424926895.0
# Name: Luu_Hanh, dtype: float64
#
# === Missing Data After Preprocessing ===
# Index              0
# Stock_Code         0
# Company_Name       0
# Date               0
# Free_Float         0
# Luu_Hanh           0
# Market_Cap         0
# Niem_Yet        1350
# Source_File        0
# dtype: int64
# C:\Users\caida\AppData\Local\Temp\ipykernel_7376\3003727649.py:135: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   nghanh_freefloat = df_long.groupby('Date').apply(
# Processing completed. duocphamyte results saved to files.
# Reading D:\nckh\data\taichinh\taichinh1.xlsx...
# Reading D:\nckh\data\taichinh\taichinh2.xlsx...
# Reading D:\nckh\data\taichinh\taichinh3.xlsx...
# Reading D:\nckh\data\taichinh\taichinh4.xlsx...
# Reading D:\nckh\data\taichinh\taichinh5.xlsx...
# Reading D:\nckh\data\taichinh\taichinh6.xlsx...
# Dropped 18 rows with missing Stock_Code, Company_Name, and Date.
#
# === First 5 rows ===
#   Index Stock_Code             Company_Name       Date   Free_Float  \
# 0     1        AAS  Chứng khoán SmartInvest 2025-10-20  229999521.0
# 1     2        AAV     Việt Tiên Sơn Địa ốc 2025-10-20   51740745.0
# 2     3        ABI        BH NH Nông Nghiệp 2025-10-20   35471671.0
# 3     4        ABW      Chứng khoán An Bình 2025-10-20   25287500.0
# 4     5       ACBS          Chứng khoán ACB 2025-10-20          0.0
#
#        Luu_Hanh      Niem_Yet  Market_Cap     Source_File
# 0  2.299995e+08  2.299995e+08         NaN  taichinh1.xlsx
# 1  6.898766e+07  6.898766e+07         NaN  taichinh1.xlsx
# 2  1.013476e+08  1.013476e+08         NaN  taichinh1.xlsx
# 3  1.011500e+08  1.011500e+08         NaN  taichinh1.xlsx
# 4  1.100000e+09  1.100000e+09         NaN  taichinh1.xlsx
#
# === Column names and info ===
# <class 'pandas.core.frame.DataFrame'>
# Index: 1148991 entries, 0 to 1149008
# Data columns (total 9 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   Index         1148991 non-null  object
#  1   Stock_Code    1146838 non-null  object
#  2   Company_Name  1146838 non-null  object
#  3   Date          1148943 non-null  datetime64[ns]
#  4   Free_Float    974297 non-null   float64
#  5   Luu_Hanh      1108813 non-null  float64
#  6   Niem_Yet      974297 non-null   float64
#  7   Market_Cap    976222 non-null   float64
#  8   Source_File   1148991 non-null  object
# dtypes: datetime64[ns](1), float64(4), object(4)
# memory usage: 87.7+ MB
# None
#
# === Missing Data Summary ===
# Column Stock_Code: 2153 missing values
# Column Company_Name: 2153 missing values
# Column Date: 48 missing values
# Column Free_Float: 174694 missing values
# Column Luu_Hanh: 40178 missing values
# Column Niem_Yet: 174694 missing values
# Column Market_Cap: 172769 missing values
#
# === Stocks with Missing Free_Float ===
# Stock_Code
# BMI    1405
# SSI    1405
# VIC    1404
# SJS    1404
# STL    1404
# Name: count, dtype: int64
#
# === Dates with Missing Free_Float ===
# Date
# 2008-12-23     20
# 2008-12-24     20
# 2008-12-25     20
# 2008-12-27     20
# 2008-12-31    177
# Name: count, dtype: int64
# Applying ffill to Free_Float within Stock_Code.
# Applying ffill to Luu_Hanh within Stock_Code.
# Applying ffill to Market_Cap within Stock_Code.
# Dropping 161132 rows with missing Free_Float, 4094 rows with missing Market_Cap, and 12520 rows with missing Luu_Hanh.
# Dropped 171426 rows with Luu_Hanh <= 0.
#
# Remaining rows after filtering: 815603 (70.98% of original)
# Unique stocks: 377
# Unique dates: 2785
#
# === After Pre-Processing ===
#          Index Stock_Code             Company_Name       Date  Free_Float  \
# 155627  155628        AAS  Chứng khoán SmartInvest 2016-05-04         0.0
# 151581  151582        AAS  Chứng khoán SmartInvest 2016-08-22         0.0
# 151529  151530        AAS  Chứng khoán SmartInvest 2016-08-23         0.0
# 151477  151478        AAS  Chứng khoán SmartInvest 2016-08-24         0.0
# 151425  151426        AAS  Chứng khoán SmartInvest 2016-08-25         0.0
#
#          Luu_Hanh  Niem_Yet  Market_Cap     Source_File
# 155627  2200000.0       0.0         0.0  taichinh1.xlsx
# 151581  2200000.0       0.0         0.0  taichinh1.xlsx
# 151529  2200000.0       0.0         0.0  taichinh1.xlsx
# 151477  2200000.0       0.0         0.0  taichinh1.xlsx
# 151425  2200000.0       0.0         0.0  taichinh1.xlsx
#
# === Debug Data ===
# Total Free_Float = 0: 353801
# Total Luu_Hanh = 0: 0
# Free_Float sum by Date: Date
# 2014-08-27    3.970918e+09
# 2014-08-28    3.970918e+09
# 2014-08-29    3.975868e+09
# 2014-09-03    3.975868e+09
# 2014-09-04    3.975867e+09
# Name: Free_Float, dtype: float64
# Luu_Hanh sum by Date: Date
# 2014-08-27    1.063306e+10
# 2014-08-28    1.063306e+10
# 2014-08-29    1.064406e+10
# 2014-09-03    1.064406e+10
# 2014-09-04    1.064406e+10
# Name: Luu_Hanh, dtype: float64
#
# === Missing Data After Preprocessing ===
# Index               0
# Stock_Code          0
# Company_Name        0
# Date                0
# Free_Float          0
# Luu_Hanh            0
# Niem_Yet        11026
# Market_Cap          0
# Source_File         0
# dtype: int64
# C:\Users\caida\AppData\Local\Temp\ipykernel_7376\3003727649.py:135: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   nghanh_freefloat = df_long.groupby('Date').apply(
# Processing completed. taichinh results saved to files.
# Reading D:\nckh\data\nganhang\ngânhang.xlsx...
# Dropped 3 rows with missing Stock_Code, Company_Name, and Date.
#
# === First 5 rows ===
#   Index  Stock_Code        Company_Name       Date    Free_Float  \
# 0     1         ABB   Ngân hàng An Bình 2025-10-01  5.175184e+08
# 1     2         ACB                 ACB 2025-10-01  4.366158e+09
# 2     3        AGRB            Agribank 2025-10-01  0.000000e+00
# 3     4         BAB     Ngân hàng Bắc Á 2025-10-01  7.524143e+08
# 4     5  BAOVIETBAN  Ngân hàng Bảo Việt 2025-10-01  0.000000e+00
#
#        Luu_Hanh      Niem_Yet    Market_Cap    Source_File
# 0  1.035037e+09  1.035037e+09  1.278788e+13  ngânhang.xlsx
# 1  5.136657e+09  5.136657e+09  1.325257e+14  ngânhang.xlsx
# 2  4.096292e+09  4.096292e+09           NaN  ngânhang.xlsx
# 3  1.003219e+09  9.580218e+08  1.344314e+13  ngânhang.xlsx
# 4  3.150000e+08  3.150000e+08           NaN  ngânhang.xlsx
#
# === Column names and info ===
# <class 'pandas.core.frame.DataFrame'>
# Index: 158546 entries, 0 to 158548
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Index         158546 non-null  object
#  1   Stock_Code    158538 non-null  object
#  2   Company_Name  158538 non-null  object
#  3   Date          158538 non-null  datetime64[ns]
#  4   Free_Float    126220 non-null  float64
#  5   Luu_Hanh      150514 non-null  float64
#  6   Niem_Yet      126220 non-null  float64
#  7   Market_Cap    139954 non-null  float64
#  8   Source_File   158546 non-null  object
# dtypes: datetime64[ns](1), float64(4), object(4)
# memory usage: 12.1+ MB
# None
#
# === Missing Data Summary ===
# Column Stock_Code: 8 missing values
# Column Company_Name: 8 missing values
# Column Date: 8 missing values
# Column Free_Float: 32326 missing values
# Column Luu_Hanh: 8032 missing values
# Column Niem_Yet: 32326 missing values
# Column Market_Cap: 18592 missing values
#
# === Stocks with Missing Free_Float ===
# Stock_Code
# PVcomBank    1482
# STB          1404
# ACB          1404
# SHB          1344
# VCB          1296
# Name: count, dtype: int64
#
# === Dates with Missing Free_Float ===
# Date
# 2008-12-23     3
# 2008-12-24     3
# 2008-12-25     3
# 2008-12-27     3
# 2008-12-31    33
# Name: count, dtype: int64
# Applying ffill to Free_Float within Stock_Code.
# Applying ffill to Luu_Hanh within Stock_Code.
# Applying ffill to Market_Cap within Stock_Code.
# Dropping 30630 rows with missing Free_Float, 229 rows with missing Market_Cap, and 3889 rows with missing Luu_Hanh.
# Dropped 10285 rows with Luu_Hanh <= 0.
#
# Remaining rows after filtering: 117631 (74.19% of original)
# Unique stocks: 49
# Unique dates: 2772
#
# === After Pre-Processing ===
#          Index Stock_Code       Company_Name       Date  Free_Float  \
# 127880  127881        ABB  Ngân hàng An Bình 2014-08-27         0.0
# 127844  127845        ABB  Ngân hàng An Bình 2014-08-28         0.0
# 127808  127809        ABB  Ngân hàng An Bình 2014-08-29         0.0
# 127772  127773        ABB  Ngân hàng An Bình 2014-09-03         0.0
# 127736  127737        ABB  Ngân hàng An Bình 2014-09-04         0.0
#
#            Luu_Hanh  Niem_Yet  Market_Cap    Source_File
# 127880  479799976.0       0.0         0.0  ngânhang.xlsx
# 127844  479799976.0       0.0         0.0  ngânhang.xlsx
# 127808  479799976.0       0.0         0.0  ngânhang.xlsx
# 127772  479799976.0       0.0         0.0  ngânhang.xlsx
# 127736  479799976.0       0.0         0.0  ngânhang.xlsx
#
# === Debug Data ===
# Total Free_Float = 0: 64212
# Total Luu_Hanh = 0: 0
# Free_Float sum by Date: Date
# 2014-08-27    5.018266e+09
# 2014-08-28    5.018266e+09
# 2014-08-29    5.018266e+09
# 2014-09-03    5.018266e+09
# 2014-09-04    5.018266e+09
# Name: Free_Float, dtype: float64
# Luu_Hanh sum by Date: Date
# 2014-08-27    2.974060e+10
# 2014-08-28    2.974060e+10
# 2014-08-29    2.974060e+10
# 2014-09-03    2.974060e+10
# 2014-09-04    2.974060e+10
# Name: Luu_Hanh, dtype: float64
#
# === Missing Data After Preprocessing ===
# Index              0
# Stock_Code         0
# Company_Name       0
# Date               0
# Free_Float         0
# Luu_Hanh           0
# Niem_Yet        1384
# Market_Cap         0
# Source_File        0
# dtype: int64
# C:\Users\caida\AppData\Local\Temp\ipykernel_7376\3003727649.py:135: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   nghanh_freefloat = df_long.groupby('Date').apply(
# Processing completed. nganhang results saved to files.
# Reading D:\nckh\data\congnghiep\congnghiep10.xlsx...
# Reading D:\nckh\data\congnghiep\congnghiep11.xlsx...
# Reading D:\nckh\data\congnghiep\congnghiep12.xlsx...
# Reading D:\nckh\data\congnghiep\congnghiep13.xlsx...
# Reading D:\nckh\data\congnghiep\congnghiep14.xlsx...
# Reading D:\nckh\data\congnghiep\congnghiep15.xlsx...
# Reading D:\nckh\data\congnghiep\congnghiep6.xlsx...
# Reading D:\nckh\data\congnghiep\congnghiep8.xlsx...
# Reading D:\nckh\data\congnghiep\congnghiep9.xlsx...
# Reading D:\nckh\data\congnghiep\congnghiep_1.xlsx...
# Reading D:\nckh\data\congnghiep\congnghiep_2.xlsx...
# Reading D:\nckh\data\congnghiep\congnghiep_3.xlsx...
# Reading D:\nckh\data\congnghiep\congnghiep_4.xlsx...
# Reading D:\nckh\data\congnghiep\congnghiep_5.xlsx...
# Reading D:\nckh\data\congnghiep\congnghiep_7_1.xlsx...
# Reading D:\nckh\data\congnghiep\congnghiep_7_2.xlsx...
# Dropped 48 rows with missing Stock_Code, Company_Name, and Date.
#
# === First 5 rows ===
#   Index Stock_Code                       Company_Name       Date   Free_Float  \
# 0     1        VSA                 Đại lý Hàng hải VN 2025-10-01    3524121.0
# 1     2        VSC                          VICONSHIP 2025-10-01  336933325.0
# 2     3        VSE          DV Đường cao tốc Việt Nam 2025-10-01    3128037.0
# 3     4        VSG                 Container Phía Nam 2025-10-01    7730800.0
# 4     5        VSI  Đầu tư và Xây dựng Cấp thoát nước 2025-10-01    4496297.0
#
#       Luu_Hanh    Market_Cap     Niem_Yet        Source_File
# 0   14096486.0  2.946166e+11   14096486.0  congnghiep10.xlsx
# 1  374370362.0  1.102521e+13  374370362.0  congnghiep10.xlsx
# 2    8937250.0  7.423280e+10    8937250.0  congnghiep10.xlsx
# 3   11044000.0  1.656600e+10   11044000.0  congnghiep10.xlsx
# 4   13199997.0  2.699399e+11   13200000.0  congnghiep10.xlsx
#
# === Column names and info ===
# <class 'pandas.core.frame.DataFrame'>
# Index: 2705181 entries, 0 to 2705228
# Data columns (total 9 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   Index         object
#  1   Stock_Code    object
#  2   Company_Name  object
#  3   Date          datetime64[ns]
#  4   Free_Float    float64
#  5   Luu_Hanh      float64
#  6   Market_Cap    float64
#  7   Niem_Yet      float64
#  8   Source_File   object
# dtypes: datetime64[ns](1), float64(4), object(4)
# memory usage: 206.4+ MB
# None
#
# === Missing Data Summary ===
# Column Stock_Code: 1936 missing values
# Column Company_Name: 128 missing values
# Column Date: 128 missing values
# Column Free_Float: 428475 missing values
# Column Luu_Hanh: 122592 missing values
# Column Market_Cap: 309904 missing values
# Column Niem_Yet: 428475 missing values
#
# === Stocks with Missing Free_Float ===
# Stock_Code
# SDS    1482
# CIC    1482
# ALP    1482
# BTC    1476
# BHV    1460
# Name: count, dtype: int64
#
# === Dates with Missing Free_Float ===
# Date
# 2008-12-23    138
# 2008-12-24    138
# 2008-12-25    139
# 2008-12-27    139
# 2008-12-31    359
# Name: count, dtype: int64
# Applying ffill to Free_Float within Stock_Code.
# Applying ffill to Luu_Hanh within Stock_Code.
# Applying ffill to Market_Cap within Stock_Code.
# Dropping 404680 rows with missing Free_Float, 10270 rows with missing Market_Cap, and 22025 rows with missing Luu_Hanh.
# Dropped 262740 rows with Luu_Hanh <= 0.
#
# Remaining rows after filtering: 2034185 (75.19% of original)
# Unique stocks: 865
# Unique dates: 3195
#
# === After Pre-Processing ===
#          Index  Stock_Code Company_Name       Date  Free_Float    Luu_Hanh  \
# 421405  124728  0302602811     Ttp Corp 2016-05-04         0.0  41658105.0
# 418757  122080  0302602811     Ttp Corp 2016-08-22         0.0  41658105.0
# 418723  122046  0302602811     Ttp Corp 2016-08-23         0.0  41658105.0
# 418689  122012  0302602811     Ttp Corp 2016-08-24         0.0  41658105.0
# 418655  121978  0302602811     Ttp Corp 2016-08-25         0.0  41658105.0
#
#         Market_Cap  Niem_Yet        Source_File
# 421405         0.0       0.0  congnghiep12.xlsx
# 418757         0.0       0.0  congnghiep12.xlsx
# 418723         0.0       0.0  congnghiep12.xlsx
# 418689         0.0       0.0  congnghiep12.xlsx
# 418655         0.0       0.0  congnghiep12.xlsx
#
# === Debug Data ===
# Total Free_Float = 0: 526499
# Total Luu_Hanh = 0: 0
# Free_Float sum by Date: Date
# 2012-12-28    0.0
# 2013-01-02    0.0
# 2013-01-03    0.0
# 2013-01-04    0.0
# 2013-01-07    0.0
# Name: Free_Float, dtype: float64
# Luu_Hanh sum by Date: Date
# 2012-12-28    112801500.0
# 2013-01-02    112801500.0
# 2013-01-03    112801500.0
# 2013-01-04    112801500.0
# 2013-01-07    112801500.0
# Name: Luu_Hanh, dtype: float64
#
# === Missing Data After Preprocessing ===
# Index               0
# Stock_Code          0
# Company_Name        0
# Date                0
# Free_Float          0
# Luu_Hanh            0
# Market_Cap          0
# Niem_Yet        19229
# Source_File         0
# dtype: int64
# C:\Users\caida\AppData\Local\Temp\ipykernel_7376\3003727649.py:135: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   nghanh_freefloat = df_long.groupby('Date').apply(
# Processing completed. congnghiep results saved to files.
# Reading D:\nckh\data\dichvutieudung\dichvutieudung2.xlsx...
# Reading D:\nckh\data\dichvutieudung\dichvutieudung3.xlsx...
# Reading D:\nckh\data\dichvutieudung\dichvutieudung4.xlsx...
# Reading D:\nckh\data\dichvutieudung\dichvutieudung5.xlsx...
# Reading D:\nckh\data\dichvutieudung\dichvutiudung1.xlsx...
# Dropped 15 rows with missing Stock_Code, Company_Name, and Date.
#
# === First 5 rows ===
#   Index Stock_Code               Company_Name       Date     Niem_Yet  \
# 0     1        HNT             Xe điện Hà Nội 2025-10-01    5500000.0
# 1     2        HOT        Du lịch - DV Hội An 2025-10-01    8000000.0
# 2     3        HTM  Thương mại Hà Nội - Hapro 2025-10-01  220000000.0
# 3     4        HTP            In SGK Hòa Phát 2025-10-01   91804980.0
# 4     5        HTT          Thương mại Hà Tây 2025-10-01   20000000.0
#
#    Free_Float     Luu_Hanh    Market_Cap           Source_File
# 0   1375000.0    5500000.0           NaN  dichvutieudung2.xlsx
# 1   1999984.0    7999937.0  1.431989e+11  dichvutieudung2.xlsx
# 2  21995860.0  219958600.0  2.287569e+12  dichvutieudung2.xlsx
# 3  91804980.0   91804980.0  2.203320e+11  dichvutieudung2.xlsx
# 4  14000000.0   20000000.0  2.800000e+10  dichvutieudung2.xlsx
#
# === Column names and info ===
# <class 'pandas.core.frame.DataFrame'>
# Index: 733843 entries, 0 to 733857
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Index         733843 non-null  object
#  1   Stock_Code    733803 non-null  object
#  2   Company_Name  733803 non-null  object
#  3   Date          733803 non-null  datetime64[ns]
#  4   Niem_Yet      640156 non-null  float64
#  5   Free_Float    640156 non-null  float64
#  6   Luu_Hanh      703536 non-null  float64
#  7   Market_Cap    602087 non-null  float64
#  8   Source_File   733843 non-null  object
# dtypes: datetime64[ns](1), float64(4), object(4)
# memory usage: 56.0+ MB
# None
#
# === Missing Data Summary ===
# Column Stock_Code: 40 missing values
# Column Company_Name: 40 missing values
# Column Date: 40 missing values
# Column Niem_Yet: 93687 missing values
# Column Free_Float: 93687 missing values
# Column Luu_Hanh: 30307 missing values
# Column Market_Cap: 131756 missing values
#
# === Stocks with Missing Free_Float ===
# Stock_Code
# HBE    1460
# VPL    1434
# PIT    1405
# PET    1405
# SAP    1404
# Name: count, dtype: int64
#
# === Dates with Missing Free_Float ===
# Date
# 2008-12-23    24
# 2008-12-24    24
# 2008-12-25    24
# 2008-12-27    24
# 2008-12-31    77
# Name: count, dtype: int64
# Applying ffill to Free_Float within Stock_Code.
# Applying ffill to Luu_Hanh within Stock_Code.
# Applying ffill to Market_Cap within Stock_Code.
# Dropping 81991 rows with missing Free_Float, 1252 rows with missing Market_Cap, and 4333 rows with missing Luu_Hanh.
# Dropped 173687 rows with Luu_Hanh <= 0.
#
# Remaining rows after filtering: 477816 (65.11% of original)
# Unique stocks: 211
# Unique dates: 2772
#
# === After Pre-Processing ===
#          Index Stock_Code  Company_Name       Date  Niem_Yet  Free_Float  \
# 314614  105780      ACSVN  ACS Việt Nam 2016-05-04       0.0         0.0
# 312662  103828      ACSVN  ACS Việt Nam 2016-08-22       0.0         0.0
# 312636  103802      ACSVN  ACS Việt Nam 2016-08-23       0.0         0.0
# 312610  103776      ACSVN  ACS Việt Nam 2016-08-24       0.0         0.0
# 312583  103749      ACSVN  ACS Việt Nam 2016-08-25       0.0         0.0
#
#           Luu_Hanh  Market_Cap           Source_File
# 314614  10800000.0         0.0  dichvutieudung3.xlsx
# 312662  10800000.0         0.0  dichvutieudung3.xlsx
# 312636  10800000.0         0.0  dichvutieudung3.xlsx
# 312610  10800000.0         0.0  dichvutieudung3.xlsx
# 312583  10800000.0         0.0  dichvutieudung3.xlsx
#
# === Debug Data ===
# Total Free_Float = 0: 167815
# Total Luu_Hanh = 0: 0
# Free_Float sum by Date: Date
# 2014-08-27    493806297.0
# 2014-08-28    493806297.0
# 2014-08-29    493806297.0
# 2014-09-03    493806297.0
# 2014-09-04    493806297.0
# Name: Free_Float, dtype: float64
# Luu_Hanh sum by Date: Date
# 2014-08-27    1.037222e+09
# 2014-08-28    1.037222e+09
# 2014-08-29    1.037222e+09
# 2014-09-03    1.037222e+09
# 2014-09-04    1.037222e+09
# Name: Luu_Hanh, dtype: float64
#
# === Missing Data After Preprocessing ===
# Index              0
# Stock_Code         0
# Company_Name       0
# Date               0
# Niem_Yet        6223
# Free_Float         0
# Luu_Hanh           0
# Market_Cap         0
# Source_File        0
# dtype: int64
# C:\Users\caida\AppData\Local\Temp\ipykernel_7376\3003727649.py:135: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   nghanh_freefloat = df_long.groupby('Date').apply(
# Processing completed. dichvutieudung results saved to files.
# Reading D:\nckh\data\tienichcd\tiemichcc1.xlsx...
# Reading D:\nckh\data\tienichcd\tienichcc2.xlsx...
# Reading D:\nckh\data\tienichcd\tienichcc3.xlsx...
# Reading D:\nckh\data\tienichcd\tienichcc4.xlsx...
# Dropped 12 rows with missing Stock_Code, Company_Name, and Date.
#
# === First 5 rows ===
#   Index Stock_Code              Company_Name       Date   Free_Float  \
# 0     1        ASP            Dầu khí An Pha 2025-10-20   16802793.0
# 1     2        AVC         Thủy điện A Vương 2025-10-20    7505205.0
# 2     3        BDW  Cấp thoát nước Bình Định 2025-10-20    2482160.0
# 3     4        BGE                BCG Energy 2025-10-20  730000000.0
# 4     5        BGW       Nước sạch Bắc Giang 2025-10-20    3629889.0
#
#       Luu_Hanh     Niem_Yet  Market_Cap      Source_File
# 0   37339542.0   37339929.0         NaN  tiemichcc1.xlsx
# 1   75052052.0   75052052.0         NaN  tiemichcc1.xlsx
# 2   12410800.0   12410800.0         NaN  tiemichcc1.xlsx
# 3  730000000.0  730000000.0         NaN  tiemichcc1.xlsx
# 4   18149446.0   18149446.0         NaN  tiemichcc1.xlsx
#
# === Column names and info ===
# <class 'pandas.core.frame.DataFrame'>
# Index: 554022 entries, 0 to 554033
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Index         554022 non-null  object
#  1   Stock_Code    553990 non-null  object
#  2   Company_Name  553990 non-null  object
#  3   Date          553990 non-null  datetime64[ns]
#  4   Free_Float    491663 non-null  float64
#  5   Luu_Hanh      536787 non-null  float64
#  6   Niem_Yet      491663 non-null  float64
#  7   Market_Cap    499107 non-null  float64
#  8   Source_File   554022 non-null  object
# dtypes: datetime64[ns](1), float64(4), object(4)
# memory usage: 42.3+ MB
# None
#
# === Missing Data Summary ===
# Column Stock_Code: 32 missing values
# Column Company_Name: 32 missing values
# Column Date: 32 missing values
# Column Free_Float: 62359 missing values
# Column Luu_Hanh: 17235 missing values
# Column Niem_Yet: 62359 missing values
# Column Market_Cap: 54915 missing values
#
# === Stocks with Missing Free_Float ===
# Stock_Code
# ASP    1405
# UIC    1404
# PJC    1404
# PGC    1404
# PGS    1404
# Name: count, dtype: int64
#
# === Dates with Missing Free_Float ===
# Date
# 2008-12-23    14
# 2008-12-24    14
# 2008-12-25    14
# 2008-12-27    14
# 2008-12-31    54
# Name: count, dtype: int64
# Applying ffill to Free_Float within Stock_Code.
# Applying ffill to Luu_Hanh within Stock_Code.
# Applying ffill to Market_Cap within Stock_Code.
# Dropping 57995 rows with missing Free_Float, 1599 rows with missing Market_Cap, and 3914 rows with missing Luu_Hanh.
# Dropped 85643 rows with Luu_Hanh <= 0.
#
# Remaining rows after filtering: 409521 (73.92% of original)
# Unique stocks: 183
# Unique dates: 2785
#
# === After Pre-Processing ===
#          Index Stock_Code    Company_Name       Date  Free_Float    Luu_Hanh  \
# 175881  175882        ASP  Dầu khí An Pha 2014-08-27  14839245.0  22829609.0
# 175858  175859        ASP  Dầu khí An Pha 2014-08-28  14839245.0  22829609.0
# 175835  175836        ASP  Dầu khí An Pha 2014-08-29  14839245.0  22829609.0
# 175812  175813        ASP  Dầu khí An Pha 2014-09-03  14839245.0  22829609.0
# 175789  175790        ASP  Dầu khí An Pha 2014-09-04  14839245.0  22829609.0
#
#           Niem_Yet    Market_Cap      Source_File
# 175881  22829996.0  1.620902e+11  tiemichcc1.xlsx
# 175858  22829996.0  1.643732e+11  tiemichcc1.xlsx
# 175835  22829996.0  1.666561e+11  tiemichcc1.xlsx
# 175812  22829996.0  1.689391e+11  tiemichcc1.xlsx
# 175789  22829996.0  1.666561e+11  tiemichcc1.xlsx
#
# === Debug Data ===
# Total Free_Float = 0: 61727
# Total Luu_Hanh = 0: 0
# Free_Float sum by Date: Date
# 2014-08-27    839557562.0
# 2014-08-28    839557562.0
# 2014-08-29    839557562.0
# 2014-09-03    839557562.0
# 2014-09-04    839557562.0
# Name: Free_Float, dtype: float64
# Luu_Hanh sum by Date: Date
# 2014-08-27    4.127816e+09
# 2014-08-28    4.127816e+09
# 2014-08-29    4.127816e+09
# 2014-09-03    4.127816e+09
# 2014-09-04    4.127816e+09
# Name: Luu_Hanh, dtype: float64
#
# === Missing Data After Preprocessing ===
# Index              0
# Stock_Code         0
# Company_Name       0
# Date               0
# Free_Float         0
# Luu_Hanh           0
# Niem_Yet        1946
# Market_Cap         0
# Source_File        0
# dtype: int64
# C:\Users\caida\AppData\Local\Temp\ipykernel_7376\3003727649.py:135: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   nghanh_freefloat = df_long.groupby('Date').apply(
# Processing completed. tienichcd results saved to files.
# Reading D:\nckh\data\nguyenvatlieu\nguyenvatlieu1.xlsx...
# Reading D:\nckh\data\nguyenvatlieu\nguyenvatlieu2.xlsx...
# Reading D:\nckh\data\nguyenvatlieu\nguyenvatlieu3.xlsx...
# Reading D:\nckh\data\nguyenvatlieu\nguyenvatlieu4.xlsx...
# Reading D:\nckh\data\nguyenvatlieu\nguyenvatlieu5.xlsx...
# Dropped 15 rows with missing Stock_Code, Company_Name, and Date.
#
# === First 5 rows ===
#   Index Stock_Code                 Company_Name       Date   Free_Float  \
# 0     1        AAA          An Phát Bioplastics 2025-10-20  196871365.0
# 1     2        AAH                Than Hợp Nhất 2025-10-20   88425000.0
# 2     3        ABS    DV Nông nghiệp Bình Thuận 2025-10-20   72000000.0
# 3     4        ACG                  Gỗ An Cường 2025-10-20   12063035.0
# 4     5        ACM  Tập đoàn Khoáng sản Á Cường 2025-10-20   51000000.0
#
#       Luu_Hanh     Niem_Yet  Market_Cap          Source_File
# 0  393742730.0  393742730.0         NaN  nguyenvatlieu1.xlsx
# 1  117900000.0  117900000.0         NaN  nguyenvatlieu1.xlsx
# 2   80000000.0   80000000.0         NaN  nguyenvatlieu1.xlsx
# 3  150787946.0  150787946.0         NaN  nguyenvatlieu1.xlsx
# 4   51000000.0   51000000.0         NaN  nguyenvatlieu1.xlsx
#
# === Column names and info ===
# <class 'pandas.core.frame.DataFrame'>
# Index: 785794 entries, 0 to 785808
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Index         785794 non-null  object
#  1   Stock_Code    785754 non-null  object
#  2   Company_Name  785754 non-null  object
#  3   Date          785754 non-null  datetime64[ns]
#  4   Free_Float    668723 non-null  float64
#  5   Luu_Hanh      753294 non-null  float64
#  6   Niem_Yet      668723 non-null  float64
#  7   Market_Cap    702625 non-null  float64
#  8   Source_File   785794 non-null  object
# dtypes: datetime64[ns](1), float64(4), object(4)
# memory usage: 60.0+ MB
# None
#
# === Missing Data Summary ===
# Column Stock_Code: 40 missing values
# Column Company_Name: 40 missing values
# Column Date: 40 missing values
# Column Free_Float: 117071 missing values
# Column Luu_Hanh: 32500 missing values
# Column Niem_Yet: 117071 missing values
# Column Market_Cap: 83169 missing values
#
# === Stocks with Missing Free_Float ===
# Stock_Code
# NVC    1482
# VIS    1460
# TNC    1405
# PLC    1405
# BMC    1405
# Name: count, dtype: int64
#
# === Dates with Missing Free_Float ===
# Date
# 2008-12-23    34
# 2008-12-24    34
# 2008-12-25    34
# 2008-12-27    34
# 2008-12-31    99
# Name: count, dtype: int64
# Applying ffill to Free_Float within Stock_Code.
# Applying ffill to Luu_Hanh within Stock_Code.
# Applying ffill to Market_Cap within Stock_Code.
# Dropping 110089 rows with missing Free_Float, 1930 rows with missing Market_Cap, and 5429 rows with missing Luu_Hanh.
# Dropped 92960 rows with Luu_Hanh <= 0.
#
# Remaining rows after filtering: 582148 (74.08% of original)
# Unique stocks: 249
# Unique dates: 2785
#
# === After Pre-Processing ===
#          Index Stock_Code         Company_Name       Date  Free_Float  \
# 164685  164686        AAA  An Phát Bioplastics 2014-08-27  35640000.0
# 164654  164655        AAA  An Phát Bioplastics 2014-08-28  35640000.0
# 164623  164624        AAA  An Phát Bioplastics 2014-08-29  35640000.0
# 164592  164593        AAA  An Phát Bioplastics 2014-09-03  35640000.0
# 164561  164562        AAA  An Phát Bioplastics 2014-09-04  35640000.0
#
#           Luu_Hanh    Niem_Yet    Market_Cap          Source_File
# 164685  39600000.0  19800000.0  6.534000e+11  nguyenvatlieu1.xlsx
# 164654  39600000.0  19800000.0  6.652800e+11  nguyenvatlieu1.xlsx
# 164623  39600000.0  19800000.0  6.652800e+11  nguyenvatlieu1.xlsx
# 164592  39600000.0  19800000.0  6.692400e+11  nguyenvatlieu1.xlsx
# 164561  39600000.0  19800000.0  6.573600e+11  nguyenvatlieu1.xlsx
#
# === Debug Data ===
# Total Free_Float = 0: 125080
# Total Luu_Hanh = 0: 0
# Free_Float sum by Date: Date
# 2014-08-27    1.585536e+09
# 2014-08-28    1.590411e+09
# 2014-08-29    1.590411e+09
# 2014-09-03    1.590411e+09
# 2014-09-04    1.590411e+09
# Name: Free_Float, dtype: float64
# Luu_Hanh sum by Date: Date
# 2014-08-27    3.349768e+09
# 2014-08-28    3.357268e+09
# 2014-08-29    3.357268e+09
# 2014-09-03    3.357268e+09
# 2014-09-04    3.357268e+09
# Name: Luu_Hanh, dtype: float64
#
# === Missing Data After Preprocessing ===
# Index              0
# Stock_Code         0
# Company_Name       0
# Date               0
# Free_Float         0
# Luu_Hanh           0
# Niem_Yet        4642
# Market_Cap         0
# Source_File        0
# dtype: int64
# C:\Users\caida\AppData\Local\Temp\ipykernel_7376\3003727649.py:135: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   nghanh_freefloat = df_long.groupby('Date').apply(
# Processing completed. nguyenvatlieu results saved to files.
# Reading D:\nckh\data\vienthong\vienthong.xlsx...
# Dropped 3 rows with missing Stock_Code, Company_Name, and Date.
#
# === First 5 rows ===
#   Index Stock_Code                            Company_Name       Date  \
# 0     1        ABC                        Truyền thông VMG 2025-10-01
# 1     2        FOX                             FPT Telecom 2025-10-01
# 2     3        MFS                        Mobifone Service 2025-10-01
# 3     4        PAI  CNTT, VT và Tự động hóa Dầu khí - PAIC 2025-10-01
# 4     5        PIA           Tin học Viễn thông Petrolimex 2025-10-01
#
#    Free_Float     Luu_Hanh     Niem_Yet    Market_Cap     Source_File
# 0  12233400.0   20389000.0   20393000.0  2.192225e+11  vienthong.xlsx
# 1  30802610.0  738763463.0  738763463.0  4.755568e+13  vienthong.xlsx
# 2   3884638.0    7062979.0    7062979.0  2.792561e+11  vienthong.xlsx
# 3     82650.0    4235290.0    4235290.0  4.870584e+10  vienthong.xlsx
# 4   1365000.0    3900000.0    3900000.0  1.131000e+11  vienthong.xlsx
#
# === Column names and info ===
# <class 'pandas.core.frame.DataFrame'>
# Index: 40495 entries, 0 to 40497
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Index         40495 non-null  object
#  1   Stock_Code    40487 non-null  object
#  2   Company_Name  40487 non-null  object
#  3   Date          40487 non-null  datetime64[ns]
#  4   Free_Float    38284 non-null  float64
#  5   Luu_Hanh      39632 non-null  float64
#  6   Niem_Yet      38284 non-null  float64
#  7   Market_Cap    33829 non-null  float64
#  8   Source_File   40495 non-null  object
# dtypes: datetime64[ns](1), float64(4), object(4)
# memory usage: 3.1+ MB
# None
#
# === Missing Data Summary ===
# Column Stock_Code: 8 missing values
# Column Company_Name: 8 missing values
# Column Date: 8 missing values
# Column Free_Float: 2211 missing values
# Column Luu_Hanh: 863 missing values
# Column Niem_Yet: 2211 missing values
# Column Market_Cap: 6666 missing values
#
# === Stocks with Missing Free_Float ===
# Stock_Code
# PTP     1174
# VGI      429
# SPTC      82
# VTT       79
# VTDS      78
# Name: count, dtype: int64
#
# === Dates with Missing Free_Float ===
# Date
# 2008-12-31    3
# 2009-12-03    1
# 2009-12-04    1
# 2009-12-07    1
# 2009-12-08    1
# Name: count, dtype: int64
# Applying ffill to Free_Float within Stock_Code.
# Applying ffill to Luu_Hanh within Stock_Code.
# Applying ffill to Market_Cap within Stock_Code.
# Dropping 1628 rows with missing Free_Float, 18 rows with missing Market_Cap, and 280 rows with missing Luu_Hanh.
# Dropped 6245 rows with Luu_Hanh <= 0.
#
# Remaining rows after filtering: 32622 (80.55% of original)
# Unique stocks: 14
# Unique dates: 2772
#
# === After Pre-Processing ===
#        Index Stock_Code      Company_Name       Date  Free_Float    Luu_Hanh  \
# 38864  38865        ABC  Truyền thông VMG 2014-08-27         0.0  20393000.0
# 38861  38862        ABC  Truyền thông VMG 2014-08-28         0.0  20393000.0
# 38858  38859        ABC  Truyền thông VMG 2014-08-29         0.0  20393000.0
# 38855  38856        ABC  Truyền thông VMG 2014-09-03         0.0  20393000.0
# 38852  38853        ABC  Truyền thông VMG 2014-09-04         0.0  20393000.0
#
#          Niem_Yet  Market_Cap     Source_File
# 38864  20393000.0         0.0  vienthong.xlsx
# 38861  20393000.0         0.0  vienthong.xlsx
# 38858  20393000.0         0.0  vienthong.xlsx
# 38855  20393000.0         0.0  vienthong.xlsx
# 38852  20393000.0         0.0  vienthong.xlsx
#
# === Debug Data ===
# Total Free_Float = 0: 16218
# Total Luu_Hanh = 0: 0
# Free_Float sum by Date: Date
# 2014-08-27    3249953.0
# 2014-08-28    3249953.0
# 2014-08-29    3249953.0
# 2014-09-03    3249953.0
# 2014-09-04    3249953.0
# Name: Free_Float, dtype: float64
# Luu_Hanh sum by Date: Date
# 2014-08-27    27193000.0
# 2014-08-28    27193000.0
# 2014-08-29    27193000.0
# 2014-09-03    27193000.0
# 2014-09-04    27193000.0
# Name: Luu_Hanh, dtype: float64
#
# === Missing Data After Preprocessing ===
# Index             0
# Stock_Code        0
# Company_Name      0
# Date              0
# Free_Float        0
# Luu_Hanh          0
# Niem_Yet        449
# Market_Cap        0
# Source_File       0
# dtype: int64
# C:\Users\caida\AppData\Local\Temp\ipykernel_7376\3003727649.py:135: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   nghanh_freefloat = df_long.groupby('Date').apply(
# Processing completed. vienthong results saved to files.
# Reading D:\nckh\data\cntt\CNTT.xlsx...
# Dropped 3 rows with missing Stock_Code, Company_Name, and Date.
#
# === First 5 rows ===
#   Index Stock_Code             Company_Name       Date    Free_Float  \
# 0     1        CKV                 CokyVina 2025-10-01  1.604800e+06
# 1     2        CMG   Tập đoàn Công nghệ CMC 2025-10-01  8.469804e+07
# 2     3        CMT  CN mạng và Truyền thông 2025-10-01  2.911112e+06
# 3     4        ELC                    ELCOM 2025-10-01  7.339320e+07
# 4     5        FPT                 FPT Corp 2025-10-01  1.447981e+09
#
#        Luu_Hanh      Niem_Yet    Market_Cap Source_File
# 0  4.012000e+06  4.050000e+06  4.734160e+10   CNTT.xlsx
# 1  2.117451e+08  2.117839e+08  8.289821e+12   CNTT.xlsx
# 2  7.277780e+06  8.000000e+06  1.001568e+11   CNTT.xlsx
# 3  1.048474e+08  1.048474e+08  2.369552e+12   CNTT.xlsx
# 4  1.703507e+09  1.703507e+09  1.591076e+14   CNTT.xlsx
#
# === Column names and info ===
# <class 'pandas.core.frame.DataFrame'>
# Index: 133726 entries, 0 to 133728
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Index         133726 non-null  object
#  1   Stock_Code    133718 non-null  object
#  2   Company_Name  133718 non-null  object
#  3   Date          133718 non-null  datetime64[ns]
#  4   Free_Float    99964 non-null   float64
#  5   Luu_Hanh      125020 non-null  float64
#  6   Niem_Yet      99964 non-null   float64
#  7   Market_Cap    126572 non-null  float64
#  8   Source_File   133726 non-null  object
# dtypes: datetime64[ns](1), float64(4), object(4)
# memory usage: 10.2+ MB
# None
#
# === Missing Data Summary ===
# Column Stock_Code: 8 missing values
# Column Company_Name: 8 missing values
# Column Date: 8 missing values
# Column Free_Float: 33762 missing values
# Column Luu_Hanh: 8706 missing values
# Column Niem_Yet: 33762 missing values
# Column Market_Cap: 7154 missing values
#
# === Stocks with Missing Free_Float ===
# Stock_Code
# TLC    1482
# FPT    1404
# ST8    1404
# SGT    1404
# SRA    1404
# Name: count, dtype: int64
#
# === Dates with Missing Free_Float ===
# Date
# 2008-12-23    13
# 2008-12-24    13
# 2008-12-25    13
# 2008-12-27    13
# 2008-12-31    28
# Name: count, dtype: int64
# Applying ffill to Free_Float within Stock_Code.
# Applying ffill to Luu_Hanh within Stock_Code.
# Applying ffill to Market_Cap within Stock_Code.
# Dropping 33237 rows with missing Free_Float, 419 rows with missing Market_Cap, and 1893 rows with missing Luu_Hanh.
# Dropped 2382 rows with Luu_Hanh <= 0.
#
# Remaining rows after filtering: 98107 (73.36% of original)
# Unique stocks: 37
# Unique dates: 2772
#
# === After Pre-Processing ===
#          Index Stock_Code Company_Name       Date  Free_Float   Luu_Hanh  \
# 100461  100462        CKV     CokyVina 2014-08-27   1786050.0  3969000.0
# 100433  100434        CKV     CokyVina 2014-08-28   1786050.0  3969000.0
# 100405  100406        CKV     CokyVina 2014-08-29   1786050.0  3969000.0
# 100377  100378        CKV     CokyVina 2014-09-03   1786050.0  3969000.0
# 100349  100350        CKV     CokyVina 2014-09-04   1786050.0  3969000.0
#
#          Niem_Yet    Market_Cap Source_File
# 100461  4050000.0  3.849930e+10   CNTT.xlsx
# 100433  4050000.0  3.969000e+10   CNTT.xlsx
# 100405  4050000.0  3.810240e+10   CNTT.xlsx
# 100377  4050000.0  3.810240e+10   CNTT.xlsx
# 100349  4050000.0  3.810240e+10   CNTT.xlsx
#
# === Debug Data ===
# Total Free_Float = 0: 18041
# Total Luu_Hanh = 0: 0
# Free_Float sum by Date: Date
# 2014-08-27    504524109.0
# 2014-08-28    504524109.0
# 2014-08-29    504524109.0
# 2014-09-03    504524109.0
# 2014-09-04    504524109.0
# Name: Free_Float, dtype: float64
# Luu_Hanh sum by Date: Date
# 2014-08-27    810588547.0
# 2014-08-28    810588547.0
# 2014-08-29    810588547.0
# 2014-09-03    810588547.0
# 2014-09-04    810588547.0
# Name: Luu_Hanh, dtype: float64
#
# === Missing Data After Preprocessing ===
# Index             0
# Stock_Code        0
# Company_Name      0
# Date              0
# Free_Float        0
# Luu_Hanh          0
# Niem_Yet        525
# Market_Cap        0
# Source_File       0
# dtype: int64
# C:\Users\caida\AppData\Local\Temp\ipykernel_7376\3003727649.py:135: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   nghanh_freefloat = df_long.groupby('Date').apply(
# Processing completed. cntt results saved to files.

# %%
# def process_free_float_data(tennganh):
#     folder_path = f"data\\raw\{tennganh}"
#     excel_files = glob.glob(os.path.join(folder_path, "*.xlsx"))

#     if not excel_files:
#         print(f"No .xlsx files found in {folder_path}")
#         return None

#     dataframes = []

#     for file in excel_files:
#         print(f"Reading {file}...")
#         try:
#             df = pd.read_excel(file, header=7)  # 8th row = header
#             df['SourceFile'] = os.path.basename(file)
#             dataframes.append(df)
#         except Exception as e:
#             print(f"Error reading {file}: {e}")
#             continue

#     if not dataframes:
#         print(f"No valid DataFrames created from files in {folder_path}")
#         return None

#     # Concatenate all DataFrames
#     df = pd.concat(dataframes, ignore_index=True)
#     df = pd.DataFrame(df)

#     # Print initial structure
#     print("=== First 5 rows ===")
#     print(df.head())
#     print("\n=== Column names and info ===")
#     print(df.info())

#     # 2. CHUẨN HÓA TÊN CỘT
#     df = df.rename(columns={
#         'Số CP Free Float\nĐơn vị: Cổ phiếu': 'Free_Float',
#         'Số CP lưu hành hiện thời\nĐơn vị: Cổ phiếu': 'Luu_Hanh',
#         'Số CP niêm yết\nĐơn vị: Cổ phiếu': 'Niem_Yet',
#         'Ngày': 'Date',
#         'Mã': 'Stock_Code',
#         'Tên công ty': 'Company_Name',
#         'Vốn hóa thị trường\nĐơn vị: VND': 'Market_Cap',
#         'STT': 'Index',
#         'SourceFile': 'Source_File'
#     })

#     # 3. CHUYỂN KIỂU DỮ LIỆU
#     # Chuyển đổi kiểu dữ liệu
#     df['Free_Float'] = pd.to_numeric(df['Free_Float'], errors='coerce')
#     df['Luu_Hanh'] = pd.to_numeric(df['Luu_Hanh'], errors='coerce')
#     df['Niem_Yet'] = pd.to_numeric(df['Niem_Yet'], errors='coerce')
#     df['Market_Cap'] = pd.to_numeric(df['Market_Cap'], errors='coerce')
#     df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

#     # Pre-process data
#     df_long = df.copy() 

#     # Convert data types and handle missing values
#     df_long['Free_Float'] = pd.to_numeric(df_long['Free_Float'], errors='coerce').fillna(0)
#     df_long['Luu_Hanh'] = pd.to_numeric(df_long['Luu_Hanh'], errors='coerce').fillna(0)
#     df_long['Niem_Yet'] = pd.to_numeric(df_long['Niem_Yet'], errors='coerce').fillna(0)
#     df_long['Market_Cap'] = pd.to_numeric(df_long['Market_Cap'], errors='coerce').fillna(0)  # Fill missing Market_Cap with 0
#     df_long['Date'] = pd.to_datetime(df_long['Date'], errors='coerce')

#     # Filter invalid data
#     df_long = df_long[df_long['Luu_Hanh'] > 0]
#     df_long = df_long[df_long['Free_Float'] <= df_long['Luu_Hanh']]
#     df_long = df_long[df_long['Free_Float'] >= 0]

#     print("\n=== After Pre-Processing ===")
#     print(df_long.head())
#     print("\n=== Debug Data ===")
#     print("Total Free_Float = 0:", (df_long['Free_Float'] == 0).sum())
#     print("Total Luu_Hanh = 0:", (df_long['Luu_Hanh'] == 0).sum())
#     print("Free_Float sum by Date:", df_long.groupby('Date')['Free_Float'].sum().head())
#     print("Luu_Hanh sum by Date:", df_long.groupby('Date')['Luu_Hanh'].sum().head())

#     # Calculate industry Free Float ratio
#     nghanh_freefloat = df_long.groupby('Date').apply(
#         lambda x: x['Free_Float'].sum() / x['Luu_Hanh'].sum() if x['Luu_Hanh'].sum() != 0 else 0
#     )
#     nghanh_freefloat = pd.DataFrame(nghanh_freefloat, columns=['Tỷ lệ FF']).reset_index()

#     # Print results
#     print(f"\n=== TỶ LỆ FREE FLOAT NGÀNH ({tennganh}) ===")
#     print(nghanh_freefloat.head(10))

#     # Save results
#     output = f'ty_le_freefloat_{tennganh}'
#     nghanh_freefloat.to_excel(f'data\processed\{output}.xlsx', index=False)

#     return nghanh_freefloat  # Return DataFrame for further use if needed

# # Example usage
# if __name__ == "__main__":
#     list_nganh = ['hangtieudung','duocphamyte','taichinh','nganhang','congnghiep','dichvutieudung',
#                   'tienichcd','nguyenvatlieu','vienthong','cntt']
#     result = process_free_float_data('duocphamyte')
#     if result is not None:
#         print("Processing completed. Results saved to files.")

# %%
# Xu ly rieng dau khi

# Step 1: Define file path
daukhi_path = r'data\raw\daukhi\daukhi.xlsx'

# Step 2: Read the Excel file
df_daukhi = pd.read_excel(daukhi_path, header=7)
df_daukhi = pd.DataFrame(df_daukhi)
# Print initial structure
print("=== First 5 rows ===")
print(df_daukhi.head())
print("\n=== Column names ===")
print(df_daukhi.columns.tolist())
# Dynamically find STT and Date columns
columns = df_daukhi.columns.tolist()
stt_col = next((col for col in columns if 'STT' in str(col).upper()), None)
date_col = next((col for col in columns if 'Ngày' in str(col)), None)

if not stt_col or not date_col:
    print(f"Error: Could not find STT or Ngày columns. Available columns: {columns}")
    exit()

print(f"Using STT column: {stt_col}")
print(f"Using Date column: {date_col}")

# Define companies and reshape with positional mapping
companies = ['BSR', 'OIL', 'PEQ', 'PLX', 'POS', 'PTV', 'PVB', 'PVC', 'PVD', 'PVE', 'PVS', 'TOS', 'PETROVN', 'BTPETROCHE']
columns_to_keep = [stt_col, date_col]
melted_dfs = []

for company in companies:
    company_cols = [col for col in columns if company in str(col)]
    if company_cols and len(company_cols) >= 4:  # Ensure at least 4 columns per company
        temp_df = df_daukhi[columns_to_keep + company_cols].copy()
        # Positional renaming (assuming order: Free_Float, Luu_Hanh, Niem_Yet, Market_Cap)
        rename_dict = {
            company_cols[0]: 'Free_Float',  # First column is Free Float
            company_cols[1]: 'Luu_Hanh',    # Second column is Outstanding Shares
            company_cols[2]: 'Niem_Yet',    # Third column is Listed Shares
            company_cols[3]: 'Market_Cap'   # Fourth column is Market Cap
        }
        temp_df = temp_df.rename(columns=rename_dict)
        # Debug: Print renamed columns
        print(f"\nCompany: {company}, Renamed columns: {temp_df.columns.tolist()}")
        temp_df['Stock_Code'] = company
        temp_df = temp_df[[stt_col, date_col, 'Stock_Code', 'Free_Float', 'Luu_Hanh', 'Niem_Yet', 'Market_Cap']]
        melted_dfs.append(temp_df)

# Concatenate
df_long = pd.concat(melted_dfs, ignore_index=True)
df_long = df_long.rename(columns={stt_col: 'Index', date_col: 'Date'})

print("=== Long Format Data ===")
print(df_long.head())

# Drop rows with all critical metadata missing
    initial_rows = len(df)
    df = df.dropna(subset=['STT','Mã', 'Tên công ty', 'Ngày'], how='all')
    print(f"Dropped {initial_rows - len(df)} rows with missing Stock_Code, Company_Name, and Date.")

    # Standardize column names
    df = df.rename(columns={
        'Số CP Free Float\nĐơn vị: Cổ phiếu': 'Free_Float',
        'Số CP lưu hành hiện thời\nĐơn vị: Cổ phiếu': 'Luu_Hanh',
        'Số CP niêm yết\nĐơn vị: Cổ phiếu': 'Niem_Yet',
        'Ngày': 'Date',
        'Mã': 'Stock_Code',
        'Tên công ty': 'Company_Name',
        'Vốn hóa thị trường\nĐơn vị: VND': 'Market_Cap',
        'STT': 'Index',
        'SourceFile': 'Source_File'
    })

    # Convert data types
    numeric_cols = ['STT','Free_Float', 'Luu_Hanh', 'Niem_Yet', 'Market_Cap']
    for col in numeric_cols:
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors='coerce')
    df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

    # Merge external Market_Cap if provided
    if external_market_cap_file:
        print(f"Loading external Market_Cap from {external_market_cap_file}")
        external_data = pd.read_csv(external_market_cap_file)
        external_data['Date'] = pd.to_datetime(external_data['Date'], errors='coerce')
        external_data = external_data[['Stock_Code', 'Date', 'Market_Cap']]
        df = df.drop(columns=['Market_Cap'], errors='ignore')
        df = df.merge(external_data, on=['Stock_Code', 'Date'], how='left')
        print("\n=== External Market_Cap Merged ===")
        print(df[['Stock_Code', 'Date', 'Market_Cap']].head())

    # Print initial structure
    print("\n=== First 5 rows ===")
    print(df.head())
    print("\n=== Column names and info ===")
    print(df.info())

    # Log missing data
    print("\n=== Missing Data Summary ===")
    for col in df.columns:
        missing_count = df[col].isna().sum()
        if missing_count > 0:
            print(f"Column {col}: {missing_count} missing values")

    # Investigate missing Free_Float
    if df['Free_Float'].isna().any():
        print("\n=== Stocks with Missing Free_Float ===")
        print(df[df['Free_Float'].isna()]['Stock_Code'].value_counts().head())
        print("\n=== Dates with Missing Free_Float ===")
        print(df[df['Free_Float'].isna()]['Date'].value_counts().sort_index().head())

    # Sort by Stock_Code and Date for consistent filling
    df = df.sort_values(['Stock_Code', 'Date'])

    # Apply ffill within Stock_Code
    for col in ['Free_Float', 'Luu_Hanh', 'Market_Cap']:
        if col in df.columns and df[col].isna().any():
            print(f"Applying ffill to {col} within Stock_Code.")
            df[col] = df.groupby('Stock_Code')[col].ffill()

    # Drop remaining missing values
    missing_free_float = df['Free_Float'].isna().sum()
    missing_market_cap = df['Market_Cap'].isna().sum()
    missing_luu_hanh = df['Luu_Hanh'].isna().sum()
    if missing_free_float > 0 or missing_market_cap > 0 or missing_luu_hanh > 0:
        print(f"Dropping {missing_free_float} rows with missing Free_Float, {missing_market_cap} rows with missing Market_Cap, and {missing_luu_hanh} rows with missing Luu_Hanh.")
        df = df.dropna(subset=['Free_Float', 'Market_Cap', 'Luu_Hanh'])

    # Handle invalid dates
    invalid_dates = df['Date'].isna().sum()
    if invalid_dates > 0:
        print(f"Dropping {invalid_dates} rows with invalid dates.")
        df = df.dropna(subset=['Date'])

    # Filter invalid data
    df_long = df[df['Luu_Hanh'] > 0]
    dropped_luu_hanh = len(df) - len(df_long)
    if dropped_luu_hanh > 0:
        print(f"Dropped {dropped_luu_hanh} rows with Luu_Hanh <= 0.")
    df_long = df_long[df_long['Free_Float'] <= df_long['Luu_Hanh']]
    df_long = df_long[df_long['Free_Float'] >= 0]

    # Log data retention
    print(f"\nRemaining rows after filtering: {len(df_long)} ({len(df_long)/initial_rows*100:.2f}% of original)")
    print(f"Unique stocks: {df_long['Stock_Code'].nunique()}")
    print(f"Unique dates: {df_long['Date'].nunique()}")

    print("\n=== After Pre-Processing ===")
    print(df_long.head())
    print("\n=== Debug Data ===")
    print("Total Free_Float = 0:", (df_long['Free_Float'] == 0).sum())
    print("Total Luu_Hanh = 0:", (df_long['Luu_Hanh'] == 0).sum())
    print("Free_Float sum by Date:", df_long.groupby('Date')['Free_Float'].sum().head())
    print("Luu_Hanh sum by Date:", df_long.groupby('Date')['Luu_Hanh'].sum().head())
    print("\n=== Missing Data After Preprocessing ===")
    print(df_long.isna().sum())

    # Calculate industry Free Float ratio
    nghanh_freefloat = df_long.groupby('Date').apply(
        lambda x: x['Free_Float'].sum() / x['Luu_Hanh'].sum() if x['Luu_Hanh'].sum() != 0 else 0
    )
    zero_luu_hanh_dates = df_long.groupby('Date').filter(lambda x: x['Luu_Hanh'].sum() == 0)['Date'].unique()
    for date in zero_luu_hanh_dates:
        print(f"Warning: Zero Luu_Hanh sum for date {date}")
    nghanh_freefloat = pd.DataFrame(nghanh_freefloat, columns=['Tỷ lệ FF']).reset_index()

# Convert data types
df_long['Free_Float'] = pd.to_numeric(df_long['Free_Float'], errors='coerce').fillna(0)
df_long['Luu_Hanh'] = pd.to_numeric(df_long['Luu_Hanh'], errors='coerce').fillna(0)
df_long['Niem_Yet'] = pd.to_numeric(df_long['Niem_Yet'], errors='coerce').fillna(0)
df_long['Market_Cap'] = pd.to_numeric(df_long['Market_Cap'], errors='coerce').fillna(0)
df_long['Date'] = pd.to_datetime(df_long['Date'], errors='coerce')

# Filter invalid data
df_long = df_long[df_long['Luu_Hanh'] > 0]
df_long = df_long[df_long['Free_Float'] <= df_long['Luu_Hanh']]
df_long = df_long[df_long['Free_Float'] >= 0]

print("\n=== After Pre-Processing ===")
print(df_long.head())
print("\n=== Debug Data ===")
print("Total Free_Float = 0:", (df_long['Free_Float'] == 0).sum())
print("Total Luu_Hanh = 0:", (df_long['Luu_Hanh'] == 0).sum())
print("Free_Float sum by Date:", df_long.groupby('Date')['Free_Float'].sum().head())
print("Luu_Hanh sum by Date:", df_long.groupby('Date')['Luu_Hanh'].sum().head())

# Calculate industry Free Float ratio
nganh_freefloat = df_long.groupby('Date').apply(
    lambda x: x['Free_Float'].sum() / x['Luu_Hanh'].sum() if x['Luu_Hanh'].sum() != 0 else 0
)
nganh_freefloat = pd.DataFrame(nganh_freefloat, columns=['Tỷ lệ FF']).reset_index()

# Print results
print("\n=== TỶ LỆ FREE FLOAT NGÀNH ===")
print(nganh_freefloat.head(10))
# Step 8: Save results
nganh_freefloat.to_excel('data\processed\ty_le_freefloat_daukhi.xlsx', index=False)
# Out:
# === First 5 rows ===
#    STT       Ngày                                 BSR  \
# 0  NaN        NaT  Số CP Free Float\nĐơn vị: Cổ phiếu
# 1    1 2025-10-01                           310049961
# 2    2 2025-09-30                           310049961
# 3    3 2025-09-29                           310049961
# 4    4 2025-09-26                           310049961
#
#                                         BSR.1  \
# 0  Số CP lưu hành hiện thời\nĐơn vị: Cổ phiếu
# 1                                  3100499616
# 2                                  3100499616
# 3                                  3100499616
# 4                                  3100499616
#
#                              BSR.2                             BSR.3  \
# 0  Vốn hóa thị trường\nĐơn vị: VND  Số CP niêm yết\nĐơn vị: Cổ phiếu
# 1                   82318264804800                        3100499616
# 2                   81233089939200                        3100499616
# 3                   83403439670400                        3100499616
# 4                   85263739440000                        3100499616
#
#                                   OIL  \
# 0  Số CP Free Float\nĐơn vị: Cổ phiếu
# 1                           155134425
# 2                           155134425
# 3                           155134425
# 4                           155134425
#
#                                         OIL.1  \
# 0  Số CP lưu hành hiện thời\nĐơn vị: Cổ phiếu
# 1                                  1034229500
# 2                                  1034229500
# 3                                  1034229500
# 4                                  1034229500
#
#                              OIL.2                             OIL.3  ...  \
# 0  Vốn hóa thị trường\nĐơn vị: VND  Số CP niêm yết\nĐơn vị: Cổ phiếu  ...
# 1                   11579233482000                         201425936  ...
# 2                   11474776302500                         201425936  ...
# 3                   11691964497500                         201425936  ...
# 4                   11855372758500                         201425936  ...
#
#                        Unnamed: 64                       Unnamed: 65  \
# 0  Vốn hóa thị trường\nĐơn vị: VND  Số CP niêm yết\nĐơn vị: Cổ phiếu
# 1                              NaN                               NaN
# 2                              NaN                               NaN
# 3                              NaN                               NaN
# 4                              NaN                               NaN
#
#                            BTPETROCHE  \
# 0  Số CP Free Float\nĐơn vị: Cổ phiếu
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#                                  BTPETROCHE.1  \
# 0  Số CP lưu hành hiện thời\nĐơn vị: Cổ phiếu
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#                       BTPETROCHE.2                      BTPETROCHE.3  \
# 0  Vốn hóa thị trường\nĐơn vị: VND  Số CP niêm yết\nĐơn vị: Cổ phiếu
# 1                              NaN                               NaN
# 2                              NaN                               NaN
# 3                              NaN                               NaN
# 4                              NaN                               NaN
#
#                           Unnamed: 70  \
# 0  Số CP Free Float\nĐơn vị: Cổ phiếu
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#                                   Unnamed: 71  \
# 0  Số CP lưu hành hiện thời\nĐơn vị: Cổ phiếu
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#                        Unnamed: 72                       Unnamed: 73
# 0  Vốn hóa thị trường\nĐơn vị: VND  Số CP niêm yết\nĐơn vị: Cổ phiếu
# 1                              NaN                               NaN
# 2                              NaN                               NaN
# 3                              NaN                               NaN
# 4                              NaN                               NaN
#
# [5 rows x 74 columns]
#
# === Column names ===
# ['STT', 'Ngày', 'BSR', 'BSR.1', 'BSR.2', 'BSR.3', 'OIL', 'OIL.1', 'OIL.2', 'OIL.3', 'PEQ', 'PEQ.1', 'PEQ.2', 'PEQ.3', 'PLX', 'PLX.1', 'PLX.2', 'PLX.3', 'POS', 'POS.1', 'POS.2', 'POS.3', 'PTV', 'PTV.1', 'PTV.2', 'PTV.3', 'PVB', 'PVB.1', 'PVB.2', 'PVB.3', 'PVC', 'PVC.1', 'PVC.2', 'PVC.3', 'PVD', 'PVD.1', 'PVD.2', 'PVD.3', 'PVE', 'PVE.1', 'PVE.2', 'PVE.3', 'PVS', 'PVS.1', 'PVS.2', 'PVS.3', 'TOS', 'TOS.1', 'TOS.2', 'TOS.3', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52', 'Unnamed: 53', 'PETROVN', 'PETROVN.1', 'PETROVN.2', 'PETROVN.3', 'Unnamed: 58', 'Unnamed: 59', 'Unnamed: 60', 'Unnamed: 61', 'Unnamed: 62', 'Unnamed: 63', 'Unnamed: 64', 'Unnamed: 65', 'BTPETROCHE', 'BTPETROCHE.1', 'BTPETROCHE.2', 'BTPETROCHE.3', 'Unnamed: 70', 'Unnamed: 71', 'Unnamed: 72', 'Unnamed: 73']
# Using STT column: STT
# Using Date column: Ngày
#
# Company: BSR, Renamed columns: ['STT', 'Ngày', 'Free_Float', 'Luu_Hanh', 'Niem_Yet', 'Market_Cap']
#
# Company: OIL, Renamed columns: ['STT', 'Ngày', 'Free_Float', 'Luu_Hanh', 'Niem_Yet', 'Market_Cap']
#
# Company: PEQ, Renamed columns: ['STT', 'Ngày', 'Free_Float', 'Luu_Hanh', 'Niem_Yet', 'Market_Cap']
#
# Company: PLX, Renamed columns: ['STT', 'Ngày', 'Free_Float', 'Luu_Hanh', 'Niem_Yet', 'Market_Cap']
#
# Company: POS, Renamed columns: ['STT', 'Ngày', 'Free_Float', 'Luu_Hanh', 'Niem_Yet', 'Market_Cap']
#
# Company: PTV, Renamed columns: ['STT', 'Ngày', 'Free_Float', 'Luu_Hanh', 'Niem_Yet', 'Market_Cap']
#
# Company: PVB, Renamed columns: ['STT', 'Ngày', 'Free_Float', 'Luu_Hanh', 'Niem_Yet', 'Market_Cap']
#
# Company: PVC, Renamed columns: ['STT', 'Ngày', 'Free_Float', 'Luu_Hanh', 'Niem_Yet', 'Market_Cap']
#
# Company: PVD, Renamed columns: ['STT', 'Ngày', 'Free_Float', 'Luu_Hanh', 'Niem_Yet', 'Market_Cap']
#
# Company: PVE, Renamed columns: ['STT', 'Ngày', 'Free_Float', 'Luu_Hanh', 'Niem_Yet', 'Market_Cap']
#
# Company: PVS, Renamed columns: ['STT', 'Ngày', 'Free_Float', 'Luu_Hanh', 'Niem_Yet', 'Market_Cap']
#
# Company: TOS, Renamed columns: ['STT', 'Ngày', 'Free_Float', 'Luu_Hanh', 'Niem_Yet', 'Market_Cap']
#
# Company: PETROVN, Renamed columns: ['STT', 'Ngày', 'Free_Float', 'Luu_Hanh', 'Niem_Yet', 'Market_Cap']
#
# Company: BTPETROCHE, Renamed columns: ['STT', 'Ngày', 'Free_Float', 'Luu_Hanh', 'Niem_Yet', 'Market_Cap']
# === Long Format Data ===
#   Index       Date Stock_Code                          Free_Float  \
# 0   NaN        NaT        BSR  Số CP Free Float\nĐơn vị: Cổ phiếu
# 1     1 2025-10-01        BSR                           310049961
# 2     2 2025-09-30        BSR                           310049961
# 3     3 2025-09-29        BSR                           310049961
# 4     4 2025-09-26        BSR                           310049961
#
#                                      Luu_Hanh  \
# 0  Số CP lưu hành hiện thời\nĐơn vị: Cổ phiếu
# 1                                  3100499616
# 2                                  3100499616
# 3                                  3100499616
# 4                                  3100499616
#
#                           Niem_Yet                        Market_Cap
# 0  Vốn hóa thị trường\nĐơn vị: VND  Số CP niêm yết\nĐơn vị: Cổ phiếu
# 1                   82318264804800                        3100499616
# 2                   81233089939200                        3100499616
# 3                   83403439670400                        3100499616
# 4                   85263739440000                        3100499616
#
# === After Pre-Processing ===
#   Index       Date Stock_Code   Free_Float      Luu_Hanh      Niem_Yet  \
# 1     1 2025-10-01        BSR  310049961.0  3.100500e+09  8.231826e+13
# 2     2 2025-09-30        BSR  310049961.0  3.100500e+09  8.123309e+13
# 3     3 2025-09-29        BSR  310049961.0  3.100500e+09  8.340344e+13
# 4     4 2025-09-26        BSR  310049961.0  3.100500e+09  8.526374e+13
# 5     5 2025-09-25        BSR  310049961.0  3.100500e+09  8.665896e+13
#
#      Market_Cap
# 1  3.100500e+09
# 2  3.100500e+09
# 3  3.100500e+09
# 4  3.100500e+09
# 5  3.100500e+09
#
# === Debug Data ===
# Total Free_Float = 0: 7368
# Total Luu_Hanh = 0: 0
# Free_Float sum by Date: Date
# 2008-12-31    0.0
# 2009-12-31    0.0
# 2010-12-21    0.0
# 2010-12-22    0.0
# 2010-12-23    0.0
# Name: Free_Float, dtype: float64
# Luu_Hanh sum by Date: Date
# 2008-12-31    247667504.0
# 2009-12-31    355658955.0
# 2010-12-21    558225532.0
# 2010-12-22    558225532.0
# 2010-12-23    558225532.0
# Name: Luu_Hanh, dtype: float64
# C:\Users\caida\AppData\Local\Temp\ipykernel_7376\1475278332.py:77: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   nganh_freefloat = df_long.groupby('Date').apply(
# === TỶ LỆ FREE FLOAT NGÀNH ===
#         Date  Tỷ lệ FF
# 0 2008-12-31       0.0
# 1 2009-12-31       0.0
# 2 2010-12-21       0.0
# 3 2010-12-22       0.0
# 4 2010-12-23       0.0
# 5 2010-12-24       0.0
# 6 2010-12-27       0.0
# 7 2010-12-28       0.0
# 8 2010-12-29       0.0
# 9 2010-12-30       0.0
